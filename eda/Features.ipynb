# %% [markdown]
# # Feature Engineering and Exploration
#
# This will create monthly features for users, and then explore the best combination of temporal attributes to retain for final data matrix

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from functools import reduce

# %%
trx = pd.read_csv('../data/historical_transactions.csv')
trx['new'] = False
merchants = pd.read_csv('../data/merchants.csv')
new_merchant_trx = pd.read_csv('../data/new_merchant_transactions.csv')
new_merchant_trx['new'] = True
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
print(trx.shape)
print(new_merchant_trx.shape)
# Out:
# (29112361, 15)
# (1963031, 15)

# %% [markdown]
# Need to de-normalize purchase amounts and loyalty scores based on the work of [raddar](https://www.kaggle.com/raddar/towards-de-anonymizing-the-data-some-insights)

# %%
new_merchant_trx['purchase_amount_new'] = np.round(new_merchant_trx['purchase_amount'] / 0.00150265118 + 497.06,2)
trx['purchase_amount_new'] = np.round(trx['purchase_amount'] / 0.00150265118 + 497.06,2)
train['target_raw'] = 2**train['target']

# %%
random.seed(903)
sample = np.random.choice(trx.card_id.unique(), size=1000, replace=False)
trx[trx.card_id.isin(sample)].card_id.unique().size
# Out:
# 1000

# %%
trx_sample = pd.concat([trx[trx.card_id.isin(sample)], new_merchant_trx[new_merchant_trx.card_id.isin(sample)]])
trx_sample.head()
# Out:
#       authorized_flag          card_id  city_id category_1  installments  \
# 21459               N  C_ID_418e92d805       69          N             0
# 21460               Y  C_ID_418e92d805       69          N             0
# 21461               N  C_ID_418e92d805       69          N             0
# 21462               Y  C_ID_418e92d805       69          N             0
# 21463               Y  C_ID_418e92d805       69          N             0
#
#       category_3  merchant_category_id      merchant_id  month_lag  \
# 21459          A                   367  M_ID_820c7b73c8        -11
# 21460          A                   278  M_ID_f86439cec0         -2
# 21461          A                   705  M_ID_1f4773aa76         -9
# 21462          A                    80  M_ID_5ba019a379        -12
# 21463          A                   367  M_ID_0f5fd331f8         -1
#
#        purchase_amount        purchase_date  category_2  state_id  \
# 21459        -0.724578  2017-03-21 20:37:54         1.0         9
# 21460        -0.727373  2017-12-05 14:58:03         1.0         9
# 21461        -0.735052  2017-05-23 11:23:15         1.0         9
# 21462        -0.596643  2017-02-02 18:13:57         1.0         9
# 21463        -0.703526  2018-01-11 10:49:36         1.0         9
#
#        subsector_id    new  purchase_amount_new
# 21459            16  False                14.86
# 21460            37  False                13.00
# 21461            33  False                 7.89
# 21462            37  False               100.00
# 21463            16  False                28.87

# %%
trx_full = pd.concat([trx, new_merchant_trx])
trx_full.shape
# Out:
# (31075392, 16)

# %%
# Cummulative number of unique merchants each month
trx_sample.sort_values(['card_id', 'month_lag']).drop_duplicates(['card_id', 'merchant_id'])\
    .groupby(['card_id', 'month_lag']).merchant_id.size().unstack().fillna(0).cumsum(axis=1)\
    .reset_index().melt(id_vars=['card_id'], var_name='month_lag', value_name='n_total_merchants')\
    .sort_values(['card_id', 'month_lag'])
# Out:
#                card_id month_lag  n_total_merchants
# 0      C_ID_003d2dcda8       -13                0.0
# 1000   C_ID_003d2dcda8       -12                0.0
# 2000   C_ID_003d2dcda8       -11                0.0
# 3000   C_ID_003d2dcda8       -10                0.0
# 4000   C_ID_003d2dcda8        -9                0.0
# 5000   C_ID_003d2dcda8        -8                0.0
# 6000   C_ID_003d2dcda8        -7                0.0
# 7000   C_ID_003d2dcda8        -6                0.0
# 8000   C_ID_003d2dcda8        -5                0.0
# 9000   C_ID_003d2dcda8        -4                0.0
# 10000  C_ID_003d2dcda8        -3                0.0
# 11000  C_ID_003d2dcda8        -2                6.0
# 12000  C_ID_003d2dcda8        -1               15.0
# 13000  C_ID_003d2dcda8         0               16.0
# 14000  C_ID_003d2dcda8         1               18.0
# 15000  C_ID_003d2dcda8         2               19.0
# 1      C_ID_0053ea2b7f       -13                0.0
# 1001   C_ID_0053ea2b7f       -12                0.0
# 2001   C_ID_0053ea2b7f       -11                0.0
# 3001   C_ID_0053ea2b7f       -10                0.0
# 4001   C_ID_0053ea2b7f        -9                0.0
# 5001   C_ID_0053ea2b7f        -8                0.0
# 6001   C_ID_0053ea2b7f        -7                0.0
# 7001   C_ID_0053ea2b7f        -6                2.0
# 8001   C_ID_0053ea2b7f        -5               12.0
# 9001   C_ID_0053ea2b7f        -4               28.0
# 10001  C_ID_0053ea2b7f        -3               37.0
# 11001  C_ID_0053ea2b7f        -2               47.0
# 12001  C_ID_0053ea2b7f        -1               52.0
# 13001  C_ID_0053ea2b7f         0               56.0
# ...                ...       ...                ...
# 2998   C_ID_ffc18beb8f       -11                7.0
# 3998   C_ID_ffc18beb8f       -10                7.0
# 4998   C_ID_ffc18beb8f        -9                9.0
# 5998   C_ID_ffc18beb8f        -8                9.0
# 6998   C_ID_ffc18beb8f        -7                9.0
# 7998   C_ID_ffc18beb8f        -6                9.0
# 8998   C_ID_ffc18beb8f        -5               10.0
# 9998   C_ID_ffc18beb8f        -4               13.0
# 10998  C_ID_ffc18beb8f        -3               13.0
# 11998  C_ID_ffc18beb8f        -2               13.0
# 12998  C_ID_ffc18beb8f        -1               13.0
# 13998  C_ID_ffc18beb8f         0               22.0
# 14998  C_ID_ffc18beb8f         1               26.0
# 15998  C_ID_ffc18beb8f         2               27.0
# 999    C_ID_ffc80f85b6       -13                0.0
# 1999   C_ID_ffc80f85b6       -12                2.0
# 2999   C_ID_ffc80f85b6       -11                9.0
# 3999   C_ID_ffc80f85b6       -10               16.0
# 4999   C_ID_ffc80f85b6        -9               22.0
# 5999   C_ID_ffc80f85b6        -8               27.0
# 6999   C_ID_ffc80f85b6        -7               28.0
# 7999   C_ID_ffc80f85b6        -6               28.0
# 8999   C_ID_ffc80f85b6        -5               29.0
# 9999   C_ID_ffc80f85b6        -4               29.0
# 10999  C_ID_ffc80f85b6        -3               30.0
# 11999  C_ID_ffc80f85b6        -2               31.0
# 12999  C_ID_ffc80f85b6        -1               31.0
# 13999  C_ID_ffc80f85b6         0               32.0
# 14999  C_ID_ffc80f85b6         1               37.0
# 15999  C_ID_ffc80f85b6         2               44.0
#
# [16000 rows x 3 columns]

# %%
# Actual unique merchants newly added each month
monthly_new_merchants = trx_full.sort_values(['card_id', 'month_lag'])\
    .drop_duplicates(['card_id', 'merchant_id'])[['card_id', 'month_lag', 'merchant_id']]
monthly_new_merchants.head(15)
# Out:
#                   card_id  month_lag      merchant_id
# 19095775  C_ID_00007093c1        -12  M_ID_a33355a1b7
# 19095845  C_ID_00007093c1        -12  M_ID_9400cf2342
# 19095896  C_ID_00007093c1        -12  M_ID_69423b34e4
# 19095787  C_ID_00007093c1        -10  M_ID_bc3f2e986e
# 19095805  C_ID_00007093c1        -10  M_ID_57df19bf28
# 19095815  C_ID_00007093c1        -10  M_ID_8261f7a734
# 19095776  C_ID_00007093c1         -9  M_ID_15446e939c
# 19095842  C_ID_00007093c1         -9  M_ID_3c6556f2dd
# 19095908  C_ID_00007093c1         -9  M_ID_109e9d2b1d
# 19095783  C_ID_00007093c1         -8  M_ID_ee8fcd02ca
# 19095793  C_ID_00007093c1         -8  M_ID_a614b6d5b0
# 19095851  C_ID_00007093c1         -8  M_ID_24e067cb2b
# 19095871  C_ID_00007093c1         -8  M_ID_0379adb435
# 19095881  C_ID_00007093c1         -8  M_ID_0dabc5a70c
# 19095795  C_ID_00007093c1         -7  M_ID_d96a11b2df

# %%
# Map card_id and month_lag to list of new merchants for that card, month
new_merch_dict = monthly_new_merchants.groupby(['card_id', 'month_lag'])\
    .apply(lambda x: list(x['merchant_id'])).unstack(0).fillna('').to_dict()

# %%
new_merch_dict['C_ID_00007093c1']

# %%
# Will subset the group to transactions only at new merchants and sum the amount
def f(group):
    new_merch = list(new_merch_dict.get(group['card_id'].iloc[0]).get(group['month_lag'].iloc[0]))
    return group[group['merchant_id'].isin(new_merch)].purchase_amount_new.sum()

# %%
# Group transactions and add total spend and new merchant spend per month per card
grouped = trx_full.groupby(['card_id', 'month_lag'])
groups = pd.DataFrame({'amt_total': grouped.purchase_amount_new.sum()})
groups['amt_new'] = grouped.apply(f)
groups.tail(13)
# Out:
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-13-de6c222f30a7> in <module>()
#       2 grouped = trx_full.groupby(['card_id', 'month_lag'])
#       3 groups = pd.DataFrame({'amt_total': grouped.purchase_amount_new.sum()})
# ----> 4 groups['amt_new'] = grouped.apply(f)
#       5 groups.tail(13)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     172                 hasattr(splitter, 'fast_apply') and axis == 0):
#     173             try:
# --> 174                 values, mutated = splitter.fast_apply(f, group_keys)
#     175                 return group_keys, values, mutated
#     176             except reduction.InvalidApply:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in fast_apply(self, f, names)
#     856         sdata = self._get_sorted_data()
#     857         results, mutated = reduction.apply_frame_axis0(sdata, f, names,
# --> 858                                                        starts, ends)
#     859
#     860         return results, mutated
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# <ipython-input-12-44c88ccba43a> in f(group)
#       2 def f(group):
#       3     new_merch = list(new_merch_dict.get(group['card_id'].iloc[0]).get(group['month_lag'].iloc[0]))
# ----> 4     return group[group['merchant_id'].isin(new_merch)].purchase_amount_new.sum()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2899                 if self.columns.nlevels > 1:
#    2900                     return self._getitem_multilevel(key)
# -> 2901                 return self._get_item_cache(key)
#    2902         except (TypeError, ValueError):
#    2903             # The TypeError correctly catches non hashable "key" (e.g. list)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3060         if res is None:
#    3061             values = self._data.get(item)
# -> 3062             res = self._box_item_values(item, values)
#    3063             cache[item] = res
#    3064             res._set_as_cached(item, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _box_item_values(self, key, values)
#    3345             return self._constructor(values.T, columns=items, index=self.index)
#    3346         else:
# -> 3347             return self._box_col_values(values, items)
#    3348
#    3349     def _box_col_values(self, values, items):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _box_col_values(self, values, items)
#    3352         """
#    3353         klass = self._constructor_sliced
# -> 3354         return klass(values, index=self.index, name=items, fastpath=True)
#    3355
#    3356     def __setitem__(self, key, value):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     266         generic.NDFrame.__init__(self, data, fastpath=True)
#     267
# --> 268         self.name = name
#     269         self._set_axis(0, index, fastpath=True)
#     270
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5077
#    5078         try:
# -> 5079             object.__getattribute__(self, name)
#    5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in name(self)
#     390         return generic.NDFrame._update_inplace(self, result, **kwargs)
#     391
# --> 392     @property
#     393     def name(self):
#     394         """
#
# KeyboardInterrupt:

# %% [markdown]
# We can check the transactions by month, merchant for this specific card (`C_ID_ffe0232b20`) to verify that our aggregation is working correctly. It does appear to be working as intended.

# %%
trx[trx.card_id == 'C_ID_ffe0232b20'].sort_values(['month_lag', 'merchant_id'])\
    [['card_id', 'merchant_id', 'month_lag', 'purchase_amount_new']]

# %%
# Add ratio representing the percent of total spent at new merchants for each month
groups['NDR'] = groups['amt_new'] / groups['amt_total']
groups.head(9)

# %%
# Add counts for number of new merchants added each month
groups['n_new_merchants'] = trx_full.sort_values(['card_id', 'month_lag'])\
    .drop_duplicates(['card_id', 'merchant_id'])\
    .groupby(['card_id', 'month_lag']).merchant_id.size().fillna(0)
groups.head(9)

# %%
# Add counts for total number of cummulative unique merchants each month
groups['n_total_merchants'] = trx_full.sort_values(['card_id', 'month_lag'])\
    .drop_duplicates(['card_id', 'merchant_id'])\
    .groupby(['card_id', 'month_lag']).merchant_id.size()\
    .unstack().fillna(0).cumsum(axis=1)\
    .reset_index().melt(id_vars=['card_id'], var_name='month_lag', value_name='n_total_merchants')\
    .groupby(['card_id', 'month_lag']).first()
groups.head(9)
